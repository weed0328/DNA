# %%
# EDA 사전 세팅
# %matplotlib inline

import time
import os
os.environ['KMP_WARNINGS'] = 'off'
from functools import reduce
import matplotlib as mpl
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) ## 모든 열을 출력한다.
import seaborn as sns  #데이터 시각화 
sns.set(font="AppleGothic", 

        rc={"axes.unicode_minus":False},
        
        style='darkgrid')

# %%
df = pd.read_csv('/Users/choejeehyuk/DNA/🚲UOS 빅데이터 알고리즘 경진대회/train.csv')

# %%
train = df.copy()

# %%
train['일시'] = train['일시'].astype(str)
train['일시'] = pd.to_datetime(train['일시'])
train['연'] = train.일시.dt.year
train['월'] = train.일시.dt.month
train['일'] = train.일시.dt.day
train['요일'] = train.일시.dt.weekday
train.drop(['일시'], axis=1, inplace = True)
train.head(10)
# Out:
#      광진구   동대문구    성동구    중랑구     연  월   일  요일
# 0  0.592  0.368  0.580  0.162  2018  1   1   0
# 1  0.840  0.614  1.034  0.260  2018  1   2   1
# 2  0.828  0.576  0.952  0.288  2018  1   3   2
# 3  0.792  0.542  0.914  0.292  2018  1   4   3
# 4  0.818  0.602  0.994  0.308  2018  1   5   4
# 5  0.618  0.522  0.696  0.228  2018  1   6   5
# 6  0.598  0.478  0.606  0.238  2018  1   7   6
# 7  0.742  0.528  0.848  0.202  2018  1   8   0
# 8  0.652  0.488  0.838  0.206  2018  1   9   1
# 9  0.500  0.406  0.636  0.160  2018  1  10   2

# %%
def get_view_df(df, target, order):
    viewd = df[['일시', target]]
    viewd = viewd.reset_index(drop=True)
    viewd = viewd.reset_index()
    print(target)
    fig, ax = plt.subplots()
    fig.set_size_inches(30, 10)
    sns.regplot(x='index',y=target, data=viewd, color = 'dodgerblue', line_kws={'color':"red"},order=order, ax=ax)
    plt.show()

# %%
column = ['광진구', '동대문구', '성동구', '중랑구']

for i in column: 
    get_view_df(train, i, 1)
# Out:
# 광진구
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 동대문구
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 성동구
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 중랑구
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46993 (\N{HANGUL SYLLABLE RANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/choejeehyuk/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
