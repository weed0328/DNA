# %%
import pandas as pd
import numpy as np
import math
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import model_selection
from sklearn.model_selection import GridSearchCV
import xgboost as xgb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_csv('/content/drive/MyDrive/1. DNA/[4]table/Embedding_train_data.csv')
test_df = pd.read_csv('/content/drive/MyDrive/1. DNA/[4]table/Embedding_test_data.csv')

# %%
sub = pd.read_csv('/content/drive/MyDrive/1. DNA/[4]table/sample_submission.csv')

# %%
train_df.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
# 3  2016-02-04  목   2601     104     220             355          0.0
# 4  2016-02-05  금   2601     278     181              34          0.0
#
#                                                 조식메뉴  \
# 0  ['모닝롤', '찐빵', '우유', '두유', '주스', '계란후라이', '호두죽'...
# 1  ['모닝롤', '단호박샌드', '우유', '두유', '주스', '계란후라이', '팥...
# 2  ['모닝롤', '베이글', '우유', '두유', '주스', '계란후라이', '표고버...
# 3  ['모닝롤', '토마토샌드', '우유', '두유', '주스', '계란후라이', '닭...
# 4  ['모닝롤', '와플', '우유', '두유', '주스', '계란후라이', '쇠고기죽...
#
#                                                 중식메뉴  \
# 0  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '오징어찌개', '쇠불고기',...
# 1  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '김치찌개', '가자미튀김',...
# 2  ['카레덮밥', '(쌀,현미흑미:국내산)', '팽이장국', '치킨핑거', '(닭고기...
# 3  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '쇠고기무국', '주꾸미볶음'...
# 4  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '떡국', '돈육씨앗강정', ...
#
#                                                 석식메뉴  ...      석식41      석식42  \
# 0  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '육개장', '자반고등어구이'...  ... -0.677969  0.026655
# 1  ['콩나물밥*양념장', '(쌀,현미흑미:국내산)', '어묵국', '유산슬', '(쇠...  ...  0.218089 -0.672441
# 2  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '청국장찌개', '황태양념구이...  ... -0.149827  0.259681
# 3  ['미니김밥*겨자장', '(쌀,현미흑미:국내산)', '우동', '멕시칸샐러드', '...  ... -0.257097 -0.550777
# 4  ['쌀밥', '잡곡밥', '(쌀,현미흑미:국내산)', '차돌박이찌개', '(쇠고기:...  ... -0.289660  0.011186
#
#        석식43      석식44      석식45      석식46      석식47      석식48      석식49  \
# 0  0.521240  0.106772 -0.151797  0.285805 -0.916271 -0.327705 -0.489872
# 1  0.787501  0.266674 -0.693809  0.412709 -0.846675 -0.540325 -0.346797
# 2  0.897299  0.419382  0.033570  0.816938 -0.607790 -0.501021  0.063332
# 3  1.180077  0.568659 -0.483393  1.447895 -0.850024 -0.630203 -0.074369
# 4  1.035358  0.692184 -0.199249  0.299185 -0.974069 -0.377276 -0.117614
#
#        석식50
# 0 -0.114326
# 1  0.396869
# 2  0.382068
# 3  0.335166
# 4 -0.063785
#
# [5 rows x 162 columns]

# %%
train_df = train_df.drop(['조식메뉴','중식메뉴','석식메뉴'], axis = 1)
train_df.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수     중식계  \
# 0  2016-02-01  월   2601      50     150             238          0.0  1039.0
# 1  2016-02-02  화   2601      50     173             319          0.0   867.0
# 2  2016-02-03  수   2601      56     180             111          0.0  1017.0
# 3  2016-02-04  목   2601     104     220             355          0.0   978.0
# 4  2016-02-05  금   2601     278     181              34          0.0   925.0
#
#      석식계       조식1  ...      석식41      석식42      석식43      석식44      석식45  \
# 0  331.0  0.345063  ... -0.677969  0.026655  0.521240  0.106772 -0.151797
# 1  560.0  0.537751  ...  0.218089 -0.672441  0.787501  0.266674 -0.693809
# 2  573.0  0.430975  ... -0.149827  0.259681  0.897299  0.419382  0.033570
# 3  525.0  0.695163  ... -0.257097 -0.550777  1.180077  0.568659 -0.483393
# 4  330.0  0.519855  ... -0.289660  0.011186  1.035358  0.692184 -0.199249
#
#        석식46      석식47      석식48      석식49      석식50
# 0  0.285805 -0.916271 -0.327705 -0.489872 -0.114326
# 1  0.412709 -0.846675 -0.540325 -0.346797  0.396869
# 2  0.816938 -0.607790 -0.501021  0.063332  0.382068
# 3  1.447895 -0.850024 -0.630203 -0.074369  0.335166
# 4  0.299185 -0.974069 -0.377276 -0.117614 -0.063785
#
# [5 rows x 159 columns]

# %%
test_df = test_df.drop(['조식메뉴','중식메뉴','석식메뉴'], axis = 1)
test_df.head()
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2021-01-27  수   2983      88     182               5        358.0
# 1  2021-01-28  목   2983     104     212             409        348.0
# 2  2021-01-29  금   2983     270     249               0        294.0
# 3  2021-02-01  월   2924     108     154             538        322.0
# 4  2021-02-02  화   2924      62     186             455        314.0
#
#         조식1       조식2       조식3  ...      석식41      석식42      석식43      석식44  \
# 0  0.318706  1.173837  0.228873  ...  0.855815 -0.676641  0.008660  0.049113
# 1  0.273322  0.871655  0.077482  ...  0.000000  0.000000  0.000000  0.000000
# 2  0.068761  1.216680  0.287047  ...  1.274020 -0.963867  0.068798  0.263769
# 3  0.051651  1.120480  0.057369  ...  1.215914 -0.308417  0.200664 -0.110430
# 4  0.405712  1.120068  0.380671  ...  2.021988 -0.430297 -0.483459 -0.619689
#
#        석식45      석식46      석식47      석식48      석식49      석식50
# 0  0.279932 -0.255711 -0.784561 -0.287553 -0.123809 -0.417225
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.199401 -0.475091 -1.022334 -0.346184  0.053542 -0.519112
# 3  0.222746 -0.128564 -0.394535 -0.758083 -0.181848 -0.035184
# 4  0.896096 -0.793497 -0.771993 -0.141780  0.286809 -0.650598
#
# [5 rows x 157 columns]

# %%
train_df = train_df.rename(columns = {'일자':'date','요일':'week'})
test_df = test_df.rename(columns = {'일자':'date','요일':'week'})

# %%
train_df.head(2)
# Out:
#          date week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01    월   2601      50     150             238          0.0
# 1  2016-02-02    화   2601      50     173             319          0.0
#
#       중식계    석식계       조식1  ...      석식41      석식42      석식43      석식44  \
# 0  1039.0  331.0  0.345063  ... -0.677969  0.026655  0.521240  0.106772
# 1   867.0  560.0  0.537751  ...  0.218089 -0.672441  0.787501  0.266674
#
#        석식45      석식46      석식47      석식48      석식49      석식50
# 0 -0.151797  0.285805 -0.916271 -0.327705 -0.489872 -0.114326
# 1 -0.693809  0.412709 -0.846675 -0.540325 -0.346797  0.396869
#
# [2 rows x 159 columns]

# %%
from pandas.core.common import temp_setattr
train_df['year'] = pd.to_datetime(train_df['date']).dt.year.astype(int)
train_df['month'] = pd.to_datetime(train_df['date']).dt.month.astype(int)
train_df['day'] = pd.to_datetime(train_df['date']).dt.day.astype(int)

test_df['year'] = pd.to_datetime(test_df['date']).dt.year.astype(int)
test_df['month'] = pd.to_datetime(test_df['date']).dt.month.astype(int)
test_df['day'] = pd.to_datetime(test_df['date']).dt.day.astype(int)

# %%
train_df.head(2)
# Out:
#          date week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01    월   2601      50     150             238          0.0
# 1  2016-02-02    화   2601      50     173             319          0.0
#
#       중식계    석식계       조식1  ...      석식44      석식45      석식46      석식47  \
# 0  1039.0  331.0  0.345063  ...  0.106772 -0.151797  0.285805 -0.916271
# 1   867.0  560.0  0.537751  ...  0.266674 -0.693809  0.412709 -0.846675
#
#        석식48      석식49      석식50  year  month  day
# 0 -0.327705 -0.489872 -0.114326  2016      2    1
# 1 -0.540325 -0.346797  0.396869  2016      2    2
#
# [2 rows x 162 columns]

# %%
test_df.head(2)
# Out:
#          date week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2021-01-27    수   2983      88     182               5        358.0
# 1  2021-01-28    목   2983     104     212             409        348.0
#
#         조식1       조식2       조식3  ...      석식44      석식45      석식46      석식47  \
# 0  0.318706  1.173837  0.228873  ...  0.049113  0.279932 -0.255711 -0.784561
# 1  0.273322  0.871655  0.077482  ...  0.000000  0.000000  0.000000  0.000000
#
#        석식48      석식49      석식50  year  month  day
# 0 -0.287553 -0.123809 -0.417225  2021      1   27
# 1  0.000000  0.000000  0.000000  2021      1   28
#
# [2 rows x 160 columns]

# %%
# 기존 날짜 피처 삭제
train_df.drop(columns=['date'], inplace=True)
test_df.drop(columns=['date'], inplace=True)

train_df.shape, test_df.shape
# Out:
# ((1205, 161), (50, 159))

# %%
train_df.replace({"week": ["월","화","수","목","금"] }, {"week": [0,1,2,3,4] }, inplace = True)
test_df.replace({"week": ["월","화","수","목","금"] }, {"week": [0,1,2,3,4] }, inplace = True)
train_df.head(3)
# Out:
#    week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수     중식계    석식계  \
# 0     0   2601      50     150             238          0.0  1039.0  331.0
# 1     1   2601      50     173             319          0.0   867.0  560.0
# 2     2   2601      56     180             111          0.0  1017.0  573.0
#
#         조식1       조식2  ...      석식44      석식45      석식46      석식47      석식48  \
# 0  0.345063  0.841029  ...  0.106772 -0.151797  0.285805 -0.916271 -0.327705
# 1  0.537751  0.772565  ...  0.266674 -0.693809  0.412709 -0.846675 -0.540325
# 2  0.430975  0.564405  ...  0.419382  0.033570  0.816938 -0.607790 -0.501021
#
#        석식49      석식50  year  month  day
# 0 -0.489872 -0.114326  2016      2    1
# 1 -0.346797  0.396869  2016      2    2
# 2  0.063332  0.382068  2016      2    3
#
# [3 rows x 161 columns]

# %%
test_df.replace({"week": ["월","화","수","목","금"] }, {"week": [0,1,2,3,4] }, inplace = True)
test_df.replace({"week": ["월","화","수","목","금"] }, {"week": [0,1,2,3,4] }, inplace = True)
test_df.head(3)
# Out:
#    week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수       조식1  \
# 0     2   2983      88     182               5        358.0  0.318706
# 1     3   2983     104     212             409        348.0  0.273322
# 2     4   2983     270     249               0        294.0  0.068761
#
#         조식2       조식3       조식4  ...      석식44      석식45      석식46      석식47  \
# 0  1.173837  0.228873 -0.016794  ...  0.049113  0.279932 -0.255711 -0.784561
# 1  0.871655  0.077482  0.143496  ...  0.000000  0.000000  0.000000  0.000000
# 2  1.216680  0.287047  0.108864  ...  0.263769  0.199401 -0.475091 -1.022334
#
#        석식48      석식49      석식50  year  month  day
# 0 -0.287553 -0.123809 -0.417225  2021      1   27
# 1  0.000000  0.000000  0.000000  2021      1   28
# 2 -0.346184  0.053542 -0.519112  2021      1   29
#
# [3 rows x 159 columns]

# %%
#날짜등이 주기성이 있다고 판단했으면 인코딩을 ex ) 카테고리로 하고 캣부스트 , 조류같은 걸 예상할 때는 다른 값으로 변경해줘야함 여기선 상관없다 !

# %%
train_df['week'] = train_df['week'].astype('category')

# %%
test_df['week'] = train_df['week'].astype('category')

# %%
train_df.isna().sum()
# Out:
# week              0
# 본사정원수             0
# 본사휴가자수            0
# 본사출장자수            0
# 본사시간외근무명령서승인건수    0
#                  ..
# 석식49              0
# 석식50              0
# year              0
# month             0
# day               0
# Length: 161, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler 

#정규화 변환
mm = MinMaxScaler()

# %%
train_df2 = train_df.drop(['중식계','석식계'], axis = 1)

# %%
train_df2
# Out:
#      week  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수       조식1  \
# 0       0   2601      50     150             238          0.0  0.345063
# 1       1   2601      50     173             319          0.0  0.537751
# 2       2   2601      56     180             111          0.0  0.430975
# 3       3   2601     104     220             355          0.0  0.695163
# 4       4   2601     278     181              34          0.0  0.519855
# ...   ...    ...     ...     ...             ...          ...       ...
# 1200    2   2983      75     198               4        391.0  0.205926
# 1201    3   2983      92     231             462        351.0 -0.045411
# 1202    4   2983     255     248               1        303.0  0.246507
# 1203    0   2983     107     153             616        327.0  0.092769
# 1204    1   2983      69     183             551        362.0  0.256987
#
#            조식2       조식3       조식4  ...      석식44      석식45      석식46  \
# 0     0.841029 -0.244781 -0.099740  ...  0.106772 -0.151797  0.285805
# 1     0.772565 -0.227728 -0.403583  ...  0.266674 -0.693809  0.412709
# 2     0.564405  0.014996 -0.049187  ...  0.419382  0.033570  0.816938
# 3     0.915111 -0.464399 -0.160095  ...  0.568659 -0.483393  1.447895
# 4     0.525534 -0.039259 -0.389989  ...  0.692184 -0.199249  0.299185
# ...        ...       ...       ...  ...       ...       ...       ...
# 1200  1.241737  0.267033  0.033066  ... -0.263557  0.738902  0.129731
# 1201  1.020490  0.032205 -0.095292  ...  0.122566  0.351240 -0.328923
# 1202  1.052156  0.344443  0.081379  ...  0.036668  0.654255 -0.277724
# 1203  1.107356  0.117192  0.020893  ... -0.062785 -0.246567 -0.333712
# 1204  1.069620  0.355096  0.144095  ...  0.876075 -0.303157  0.334318
#
#           석식47      석식48      석식49      석식50  year  month  day
# 0    -0.916271 -0.327705 -0.489872 -0.114326  2016      2    1
# 1    -0.846675 -0.540325 -0.346797  0.396869  2016      2    2
# 2    -0.607790 -0.501021  0.063332  0.382068  2016      2    3
# 3    -0.850024 -0.630203 -0.074369  0.335166  2016      2    4
# 4    -0.974069 -0.377276 -0.117614 -0.063785  2016      2    5
# ...        ...       ...       ...       ...   ...    ...  ...
# 1200  0.395461 -0.805688 -0.497606  0.216988  2021      1   20
# 1201 -0.620603 -0.696990  0.313707  0.084509  2021      1   21
# 1202 -0.561344 -0.290120 -0.088212 -0.819337  2021      1   22
# 1203  0.029828 -0.845187 -0.185106 -0.561755  2021      1   25
# 1204 -0.727694 -1.244185 -0.175153 -0.084898  2021      1   26
#
# [1205 rows x 159 columns]

# %%
dd = train_df2.iloc[:, 1:-3]

# %%
dt = test_df.iloc[:,1:-3]

# %%
# train 스케일링
scale_cols = dd.columns
df_scaled = mm.fit_transform(train_df[scale_cols])
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = scale_cols

df_scaled
# Out:
#          본사정원수    본사휴가자수    본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수       조식1  \
# 0     0.000000  0.022481  0.323442        0.227969     0.000000  0.509308
# 1     0.000000  0.022481  0.391691        0.305556     0.000000  0.666035
# 2     0.000000  0.027477  0.412463        0.106322     0.000000  0.579186
# 3     0.000000  0.067444  0.531157        0.340038     0.000000  0.794069
# 4     0.000000  0.212323  0.415430        0.032567     0.000000  0.651479
# ...        ...       ...       ...             ...          ...       ...
# 1200  0.542614  0.043297  0.465875        0.003831     0.733583  0.396137
# 1201  0.542614  0.057452  0.563798        0.442529     0.658537  0.191706
# 1202  0.542614  0.193172  0.614243        0.000958     0.568480  0.429144
# 1203  0.542614  0.069942  0.332344        0.590038     0.613508  0.304097
# 1204  0.542614  0.038301  0.421365        0.527778     0.679174  0.437669
#
#            조식2       조식3       조식4       조식5  ...      석식41      석식42  \
# 0     0.622950  0.541768  0.400148  0.703082  ...  0.164914  0.365596
# 1     0.572860  0.550429  0.055091  0.688134  ...  0.350518  0.146995
# 2     0.420564  0.673700  0.457558  0.722243  ...  0.274310  0.438461
# 3     0.677150  0.430232  0.331606  0.711087  ...  0.252091  0.185038
# 4     0.392125  0.646145  0.070529  0.745093  ...  0.245346  0.360759
# ...        ...       ...       ...       ...  ...       ...       ...
# 1200  0.916118  0.801701  0.550967  0.263018  ...  0.337892  0.342153
# 1201  0.754248  0.682439  0.405199  0.346025  ...  0.446457  0.251244
# 1202  0.777416  0.841015  0.605833  0.316439  ...  0.522061  0.154516
# 1203  0.817802  0.725602  0.537143  0.360469  ...  0.531137  0.374476
# 1204  0.790193  0.846425  0.677057  0.059041  ...  0.203379  0.262884
#
#           석식43      석식44      석식45      석식46      석식47      석식48      석식49  \
# 0     0.545378  0.310087  0.316197  0.597742  0.454880  0.480892  0.226945
# 1     0.642989  0.366200  0.167465  0.630739  0.480192  0.414629  0.293238
# 2     0.683240  0.419788  0.367064  0.735843  0.567076  0.426878  0.483270
# 3     0.786906  0.472172  0.225205  0.899900  0.478974  0.386618  0.419467
# 4     0.733852  0.515519  0.303176  0.601222  0.433859  0.465443  0.399429
# ...        ...       ...       ...       ...       ...       ...       ...
# 1200  0.543685  0.180132  0.560612  0.557161  0.931962  0.331928  0.223361
# 1201  0.395963  0.315629  0.454235  0.437906  0.562416  0.365804  0.599280
# 1202  0.399177  0.285486  0.537384  0.451218  0.583968  0.492605  0.413052
# 1203  0.431320  0.250586  0.290192  0.436660  0.798980  0.319618  0.368157
# 1204  0.627401  0.580050  0.274663  0.610356  0.523466  0.195270  0.372769
#
#           석식50
# 0     0.482791
# 1     0.665451
# 2     0.660162
# 3     0.643403
# 4     0.500850
# ...        ...
# 1200  0.601176
# 1201  0.553839
# 1202  0.230876
# 1203  0.322915
# 1204  0.493306
#
# [1205 rows x 155 columns]

# %%
# test 스케일링
scale_cols = dt.columns
dt_scaled = mm.transform(test_df[scale_cols])
dt_scaled = pd.DataFrame(dt_scaled)
dt_scaled.columns = scale_cols

dt_scaled
# Out:
#        본사정원수    본사휴가자수    본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수       조식1  \
# 0   0.542614  0.054122  0.418398        0.004789     0.671670  0.487869
# 1   0.542614  0.067444  0.507418        0.391762     0.652908  0.450955
# 2   0.542614  0.205662  0.617211        0.000000     0.551595  0.284570
# 3   0.458807  0.070774  0.335312        0.515326     0.604128  0.270653
# 4   0.458807  0.032473  0.430267        0.435824     0.589118  0.558638
# 5   0.458807  0.029975  0.468843        0.004789     0.536585  0.373675
# 6   0.458807  0.031640  0.504451        0.455939     0.540338  0.292359
# 7   0.458807  0.121565  0.626113        0.000000     0.480300  0.278093
# 8   0.458807  0.054122  0.394659        0.660920     0.617261  0.301714
# 9   0.458807  0.059117  0.421365        0.519157     0.617261  0.329916
# 10  0.458807  0.388010  0.275964        0.000000     0.437148  0.452384
# 11  0.458807  0.129059  0.267062        0.761494     0.666041  0.206827
# 12  0.458807  0.039134  0.397626        0.780651     0.774859  0.373317
# 13  0.458807  0.044963  0.415430        0.002874     0.711069  0.372941
# 14  0.458807  0.049958  0.611276        0.568966     0.634146  0.233937
# 15  0.458807  0.127394  0.673591        0.000958     0.525328  0.385207
# 16  0.458807  0.068276  0.462908        0.779693     0.463415  0.223866
# 17  0.458807  0.043297  0.471810        0.750000     0.437148  0.164810
# 18  0.458807  0.044963  0.575668        0.002874     0.439024  0.345234
# 19  0.458807  0.056619  0.626113        0.560345     0.440901  0.305457
# 20  0.458807  0.198168  0.706231        0.000958     0.335835  0.423021
# 21  0.531250  0.096586  0.370920        0.748084     0.465291  0.278449
# 22  0.531250  0.022481  0.456973        0.000958     0.547842  0.400630
# 23  0.531250  0.040799  0.578635        0.714559     0.493433  0.258115
# 24  0.531250  0.112406  0.640950        0.001916     0.424015  0.427277
# 25  0.531250  0.061615  0.382789        0.899425     0.495310  0.320948
# 26  0.531250  0.044130  0.382789        0.960728     0.529081  0.408606
# 27  0.531250  0.039967  0.427300        0.000958     0.508443  0.382966
# 28  0.531250  0.058285  0.540059        0.583333     0.489681  0.378750
# 29  0.531250  0.181515  0.590504        0.000000     0.470919  0.582278
# 30  0.531250  0.085762  0.317507        0.827586     0.589118  0.327315
# 31  0.531250  0.042465  0.400593        0.630268     0.752345  0.454097
# 32  0.531250  0.055787  0.448071        0.003831     0.696060  0.453857
# 33  0.531250  0.069109  0.563798        0.498084     0.658537  0.305359
# 34  0.531250  0.191507  0.635015        0.000000     0.499062  0.488992
# 35  0.531250  0.091590  0.370920        0.677203     0.656660  0.313634
# 36  0.531250  0.049126  0.486647        0.659004     0.654784  0.422600
# 37  0.531250  0.053289  0.572700        0.000000     0.589118  0.400591
# 38  0.531250  0.079101  0.649852        0.422414     0.557223  0.316317
# 39  0.531250  0.239800  0.667656        0.000000     0.429644  0.395199
# 40  0.531250  0.081599  0.406528        0.632184     0.596623  0.330330
# 41  0.531250  0.049958  0.465875        0.598659     0.587242  0.410262
# 42  0.531250  0.052456  0.522255        0.000000     0.594747  0.425934
# 43  0.528409  0.054122  0.637982        0.377395     0.568480  0.377710
# 44  0.528409  0.209825  0.685460        0.000000     0.420263  0.440533
# 45  0.528409  0.084929  0.394659        0.674330     0.621013  0.302462
# 46  0.528409  0.044130  0.382789        0.609195     0.682927  0.415532
# 47  0.528409  0.060783  0.513353        0.000958     0.626642  0.400373
# 48  0.528409  0.068276  0.584570        0.487548     0.607880  0.236551
# 49  0.528409  0.196503  0.673591        0.000000     0.429644  0.606883
#
#          조식2       조식3       조식4       조식5  ...      석식41      석식42      석식43  \
# 0   0.866441  0.782321  0.494345  0.217995  ...  0.482612  0.145681  0.357469
# 1   0.645356  0.705434  0.676377  0.460899  ...  0.305344  0.357261  0.354294
# 2   0.897786  0.811865  0.637047  0.322710  ...  0.569236  0.055868  0.379515
# 3   0.827404  0.695220  0.594668  0.314394  ...  0.557200  0.260822  0.427856
# 4   0.827102  0.859413  0.867249  0.240834  ...  0.724165  0.222711  0.177060
# 5   0.980996  0.746250  0.528384  0.327268  ...  0.305344  0.357261  0.354294
# 6   0.663593  0.864073  0.805464  0.484263  ...  0.569236  0.055868  0.379515
# 7   0.911101  0.964048  0.613334  0.193145  ...  0.138472  0.063668  0.759030
# 8   0.674441  0.864622  0.497101  0.410160  ...  0.541012  0.108659  0.326711
# 9   0.837770  0.785933  0.351278  0.201361  ...  0.697744  0.229935  0.243168
# 10  0.951950  0.790277  0.528920  0.288321  ...  0.627368  0.073643  0.318286
# 11  0.663529  0.745570  0.589562  0.339046  ...  0.489734  0.203460  0.458062
# 12  0.576970  0.731347  0.521344  0.378635  ...  0.513229  0.138281  0.378510
# 13  0.818392  0.801412  0.514740  0.266279  ...  0.404808  0.496094  0.527550
# 14  0.705012  0.683595  0.631758  0.349305  ...  1.000000  0.048069  0.000000
# 15  0.707007  0.832675  0.461180  0.182329  ...  0.526589  0.147807  0.388687
# 16  0.775573  0.657026  0.524967  0.365348  ...  0.388182  0.155043  0.448315
# 17  0.604078  0.688573  0.698481  0.577703  ...  0.485101  0.247923  0.410861
# 18  0.854839  0.783453  0.454049  0.497531  ...  0.138472  0.063668  0.759030
# 19  0.838866  0.645949  0.521028  0.337134  ...  0.569236  0.055868  0.379515
# 20  0.959102  0.725747  0.464286  0.298144  ...  0.552780  0.180719  0.426602
# 21  0.743335  0.593339  0.532790  0.291643  ...  0.569236  0.055868  0.379515
# 22  0.809712  0.884532  0.419951  0.234114  ...  1.000000  0.048069  0.000000
# 23  0.874658  0.622797  0.500857  0.325421  ...  0.569236  0.055868  0.379515
# 24  0.765550  0.706750  0.559273  0.383753  ...  0.138472  0.063668  0.759030
# 25  0.763101  0.655989  0.494348  0.301413  ...  0.459665  0.169139  0.392735
# 26  0.992778  0.794195  0.521871  0.239630  ...  0.487247  0.194934  0.398658
# 27  0.687688  0.780678  0.162318  0.328622  ...  0.532768  0.166296  0.385353
# 28  0.551182  0.595542  0.498659  0.435977  ...  0.305344  0.357261  0.354294
# 29  0.692367  0.848224  0.493499  0.291123  ...  0.497495  0.190145  0.419054
# 30  0.541960  0.615838  0.603893  0.374427  ...  0.138472  0.063668  0.759030
# 31  0.960700  0.800892  0.526969  0.314512  ...  0.501711  0.152146  0.397344
# 32  1.047156  0.770247  0.420747  0.269292  ...  0.478577  0.223671  0.388587
# 33  0.814692  0.650561  0.489119  0.340174  ...  0.309430  0.276091  0.788562
# 34  0.849256  0.760227  0.393776  0.309919  ...  0.499515  0.510517  0.339680
# 35  0.724472  0.681811  0.429720  0.488752  ...  0.498477  0.043313  0.409064
# 36  0.916466  0.744396  0.416322  0.330904  ...  0.221065  0.202534  0.706171
# 37  1.043957  0.754815  0.336292  0.413677  ...  0.471075  0.222957  0.414888
# 38  0.549308  0.623394  0.428391  0.374270  ...  0.439669  0.175145  0.428441
# 39  0.756507  0.717888  0.363633  0.419946  ...  0.569236  0.055868  0.379515
# 40  0.833041  0.622321  0.437278  0.353902  ...  0.138472  0.063668  0.759030
# 41  0.976759  0.757091  0.572031  0.326579  ...  0.138472  0.063668  0.759030
# 42  0.841761  0.874176  0.425146  0.354828  ...  0.485101  0.247923  0.410861
# 43  0.718933  0.624401  0.470144  0.488576  ...  0.516181  0.000000  0.577730
# 44  1.001155  0.817293  0.607284  0.253352  ...  0.514564  0.003935  0.178560
# 45  0.856125  0.645822  0.458597  0.312994  ...  0.430478  0.262807  0.528421
# 46  0.885692  0.870351  0.522694  0.397519  ...  0.138472  0.063668  0.759030
# 47  0.831431  0.757119  0.209118  0.209957  ...  0.180753  0.084480  0.574150
# 48  0.603574  0.546386  0.480796  0.546198  ...  1.000000  0.048069  0.000000
# 49  0.924220  0.811949  0.740114  0.262696  ...  0.486538  0.214397  0.392195
#
#         석식44      석식45      석식46      석식47      석식48      석식49      석식50
# 0   0.289854  0.434667  0.456942  0.502784  0.493405  0.396559  0.374559
# 1   0.272619  0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 2   0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 3   0.233867  0.418975  0.490002  0.644637  0.346764  0.369667  0.511070
# 4   0.055158  0.603747  0.317111  0.507354  0.538836  0.586817  0.291170
# 5   0.272619  0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 6   0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 7   0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 8   0.289500  0.433144  0.424059  0.561730  0.450340  0.507680  0.355378
# 9  -0.118688  0.531403  0.232778  0.607676  0.465375  0.752809  0.321469
# 10  0.190721  0.332544  0.396751  0.531288  0.307026  0.493065  0.310596
# 11  0.316323  0.495649  0.486459  0.610425  0.496529  0.444155  0.389634
# 12  0.296820  0.420019  0.436348  0.518616  0.446936  0.474735  0.370918
# 13  0.158413  0.659986  0.606099  1.010483  0.408458  0.422616  1.001235
# 14  0.018967  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 15  0.336191  0.397639  0.423982  0.516879  0.465972  0.552408  0.421263
# 16  0.319095  0.516485  0.478400  0.462598  0.556053  0.438948  0.466847
# 17  0.342394  0.449698  0.432245  0.521874  0.333134  0.700853  0.586053
# 18  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 19  0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 20  0.099419  0.477718  0.520542  0.502315  0.725153  0.164222  0.451831
# 21  0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 22  0.018967  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 23  0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 24  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 25  0.246101  0.332410  0.399684  0.600940  0.517718  0.460170  0.490646
# 26  0.249360  0.417959  0.494883  0.597199  0.525223  0.457457  0.448879
# 27  0.300103  0.461192  0.458476  0.594586  0.430512  0.485485  0.318285
# 28  0.272619  0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 29  0.272558  0.419315  0.469396  0.581632  0.480964  0.411863  0.425667
# 30  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 31  0.295034  0.458703  0.398282  0.545170  0.588394  0.434107  0.421567
# 32  0.227486  0.495903  0.568477  0.590161  0.580982  0.395486  0.509727
# 33  0.608264  0.339846  0.726229  0.627129  0.271858  0.308801  0.478983
# 34  0.098908  0.720998  0.402597  0.437898  0.790417  0.332160  0.586029
# 35  0.321643  0.347902  0.400515  0.643057  0.298954  0.497739  0.258129
# 36  0.475868  0.320565  0.692642  0.851820  0.282110  0.129555  0.659557
# 37  0.237561  0.444560  0.498673  0.641809  0.429285  0.451075  0.401751
# 38  0.296971  0.425300  0.460544  0.575166  0.523967  0.440644  0.423521
# 39  0.365180  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 40  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 41  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 42  0.342394  0.449698  0.432245  0.521874  0.333134  0.700853  0.586053
# 43  0.473711  0.617154  0.386846  0.348615  0.408872  0.701357  0.135933
# 44  0.130709  0.254754  0.521931  0.671862  0.263578  0.656016  0.434522
# 45  0.363102  0.436025  0.394389  0.404718  0.420030  0.461737  0.411912
# 46  0.711394  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 47  0.394131  0.098101  0.664575  0.891377  0.123331  0.428388  0.463154
# 48  0.018967  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 49  0.256425  0.433298  0.493377  0.617264  0.463222  0.444974  0.407696
#
# [50 rows x 155 columns]

# %%
scale_cols
# Out:
# Index(['본사정원수', '본사휴가자수', '본사출장자수', '본사시간외근무명령서승인건수', '현본사소속재택근무자수', '조식1',
#        '조식2', '조식3', '조식4', '조식5',
#        ...
#        '석식41', '석식42', '석식43', '석식44', '석식45', '석식46', '석식47', '석식48', '석식49',
#        '석식50'],
#       dtype='object', length=155)

# %%
# 중석식계스케일링
ff_scaled = mm.fit_transform(train_df[['중식계','석식계']])
ff_scaled = pd.DataFrame(ff_scaled, columns = ['중식계','석식계'])


ff_scaled
# Out:
#            중식계       석식계
# 0     0.638865  0.365746
# 1     0.490972  0.618785
# 2     0.619948  0.633149
# 3     0.586414  0.580110
# 4     0.540843  0.364641
# ...        ...       ...
# 1200  0.685297  0.465193
# 1201  0.460877  0.390055
# 1202  0.243336  0.239779
# 1203  0.730009  0.554696
# 1204  0.618229  0.530387
#
# [1205 rows x 2 columns]

# %%
train_df[['중식계','석식계']]
# Out:
#          중식계    석식계
# 0     1039.0  331.0
# 1      867.0  560.0
# 2     1017.0  573.0
# 3      978.0  525.0
# 4      925.0  330.0
# ...      ...    ...
# 1200  1093.0  421.0
# 1201   832.0  353.0
# 1202   579.0  217.0
# 1203  1145.0  502.0
# 1204  1015.0  480.0
#
# [1205 rows x 2 columns]

# %%
tttt = train_df[['week','year','month','day']]

# %%
train_df = pd.concat([tttt, ff_scaled,df_scaled], axis = 1)

# %%
train_df
# Out:
#      week  year  month  day       중식계       석식계     본사정원수    본사휴가자수    본사출장자수  \
# 0       0  2016      2    1  0.638865  0.365746  0.000000  0.022481  0.323442
# 1       1  2016      2    2  0.490972  0.618785  0.000000  0.022481  0.391691
# 2       2  2016      2    3  0.619948  0.633149  0.000000  0.027477  0.412463
# 3       3  2016      2    4  0.586414  0.580110  0.000000  0.067444  0.531157
# 4       4  2016      2    5  0.540843  0.364641  0.000000  0.212323  0.415430
# ...   ...   ...    ...  ...       ...       ...       ...       ...       ...
# 1200    2  2021      1   20  0.685297  0.465193  0.542614  0.043297  0.465875
# 1201    3  2021      1   21  0.460877  0.390055  0.542614  0.057452  0.563798
# 1202    4  2021      1   22  0.243336  0.239779  0.542614  0.193172  0.614243
# 1203    0  2021      1   25  0.730009  0.554696  0.542614  0.069942  0.332344
# 1204    1  2021      1   26  0.618229  0.530387  0.542614  0.038301  0.421365
#
#       본사시간외근무명령서승인건수  ...      석식41      석식42      석식43      석식44      석식45  \
# 0           0.227969  ...  0.164914  0.365596  0.545378  0.310087  0.316197
# 1           0.305556  ...  0.350518  0.146995  0.642989  0.366200  0.167465
# 2           0.106322  ...  0.274310  0.438461  0.683240  0.419788  0.367064
# 3           0.340038  ...  0.252091  0.185038  0.786906  0.472172  0.225205
# 4           0.032567  ...  0.245346  0.360759  0.733852  0.515519  0.303176
# ...              ...  ...       ...       ...       ...       ...       ...
# 1200        0.003831  ...  0.337892  0.342153  0.543685  0.180132  0.560612
# 1201        0.442529  ...  0.446457  0.251244  0.395963  0.315629  0.454235
# 1202        0.000958  ...  0.522061  0.154516  0.399177  0.285486  0.537384
# 1203        0.590038  ...  0.531137  0.374476  0.431320  0.250586  0.290192
# 1204        0.527778  ...  0.203379  0.262884  0.627401  0.580050  0.274663
#
#           석식46      석식47      석식48      석식49      석식50
# 0     0.597742  0.454880  0.480892  0.226945  0.482791
# 1     0.630739  0.480192  0.414629  0.293238  0.665451
# 2     0.735843  0.567076  0.426878  0.483270  0.660162
# 3     0.899900  0.478974  0.386618  0.419467  0.643403
# 4     0.601222  0.433859  0.465443  0.399429  0.500850
# ...        ...       ...       ...       ...       ...
# 1200  0.557161  0.931962  0.331928  0.223361  0.601176
# 1201  0.437906  0.562416  0.365804  0.599280  0.553839
# 1202  0.451218  0.583968  0.492605  0.413052  0.230876
# 1203  0.436660  0.798980  0.319618  0.368157  0.322915
# 1204  0.610356  0.523466  0.195270  0.372769  0.493306
#
# [1205 rows x 161 columns]

# %%
train_df.columns
# Out:
# Index(['week', 'year', 'month', 'day', '본사정원수', '본사휴가자수', '본사출장자수',
#        '본사시간외근무명령서승인건수', '현본사소속재택근무자수', '중식계',
#        ...
#        '석식40', '석식41', '석식42', '석식43', '석식44', '석식45', '석식46', '석식47', '석식48',
#        '석식49'],
#       dtype='object', length=160)

# %%
ttss = test_df[['week','year','month','day']]

# %%
test_df = pd.concat([ttss, dt_scaled], axis = 1)

# %%
test_df
# Out:
#    week  year  month  day     본사정원수    본사휴가자수    본사출장자수  본사시간외근무명령서승인건수  \
# 0     0  2021      1   27  0.542614  0.054122  0.418398        0.004789
# 1     1  2021      1   28  0.542614  0.067444  0.507418        0.391762
# 2     2  2021      1   29  0.542614  0.205662  0.617211        0.000000
# 3     3  2021      2    1  0.458807  0.070774  0.335312        0.515326
# 4     4  2021      2    2  0.458807  0.032473  0.430267        0.435824
# 5     3  2021      2    3  0.458807  0.029975  0.468843        0.004789
# 6     4  2021      2    4  0.458807  0.031640  0.504451        0.455939
# 7     0  2021      2    5  0.458807  0.121565  0.626113        0.000000
# 8     1  2021      2    8  0.458807  0.054122  0.394659        0.660920
# 9     2  2021      2    9  0.458807  0.059117  0.421365        0.519157
# 10    3  2021      2   10  0.458807  0.388010  0.275964        0.000000
# 11    4  2021      2   15  0.458807  0.129059  0.267062        0.761494
# 12    0  2021      2   16  0.458807  0.039134  0.397626        0.780651
# 13    1  2021      2   17  0.458807  0.044963  0.415430        0.002874
# 14    2  2021      2   18  0.458807  0.049958  0.611276        0.568966
# 15    3  2021      2   19  0.458807  0.127394  0.673591        0.000958
# 16    4  2021      2   22  0.458807  0.068276  0.462908        0.779693
# 17    0  2021      2   23  0.458807  0.043297  0.471810        0.750000
# 18    2  2021      2   24  0.458807  0.044963  0.575668        0.002874
# 19    3  2021      2   25  0.458807  0.056619  0.626113        0.560345
# 20    4  2021      2   26  0.458807  0.198168  0.706231        0.000958
# 21    0  2021      3    2  0.531250  0.096586  0.370920        0.748084
# 22    1  2021      3    3  0.531250  0.022481  0.456973        0.000958
# 23    2  2021      3    4  0.531250  0.040799  0.578635        0.714559
# 24    3  2021      3    5  0.531250  0.112406  0.640950        0.001916
# 25    4  2021      3    8  0.531250  0.061615  0.382789        0.899425
# 26    0  2021      3    9  0.531250  0.044130  0.382789        0.960728
# 27    1  2021      3   10  0.531250  0.039967  0.427300        0.000958
# 28    2  2021      3   11  0.531250  0.058285  0.540059        0.583333
# 29    3  2021      3   12  0.531250  0.181515  0.590504        0.000000
# 30    4  2021      3   15  0.531250  0.085762  0.317507        0.827586
# 31    0  2021      3   16  0.531250  0.042465  0.400593        0.630268
# 32    1  2021      3   17  0.531250  0.055787  0.448071        0.003831
# 33    2  2021      3   18  0.531250  0.069109  0.563798        0.498084
# 34    3  2021      3   19  0.531250  0.191507  0.635015        0.000000
# 35    4  2021      3   22  0.531250  0.091590  0.370920        0.677203
# 36    0  2021      3   23  0.531250  0.049126  0.486647        0.659004
# 37    1  2021      3   24  0.531250  0.053289  0.572700        0.000000
# 38    2  2021      3   25  0.531250  0.079101  0.649852        0.422414
# 39    3  2021      3   26  0.531250  0.239800  0.667656        0.000000
# 40    4  2021      3   29  0.531250  0.081599  0.406528        0.632184
# 41    0  2021      3   30  0.531250  0.049958  0.465875        0.598659
# 42    1  2021      3   31  0.531250  0.052456  0.522255        0.000000
# 43    2  2021      4    1  0.528409  0.054122  0.637982        0.377395
# 44    3  2021      4    2  0.528409  0.209825  0.685460        0.000000
# 45    4  2021      4    5  0.528409  0.084929  0.394659        0.674330
# 46    0  2021      4    6  0.528409  0.044130  0.382789        0.609195
# 47    1  2021      4    7  0.528409  0.060783  0.513353        0.000958
# 48    3  2021      4    8  0.528409  0.068276  0.584570        0.487548
# 49    4  2021      4    9  0.528409  0.196503  0.673591        0.000000
#
#     현본사소속재택근무자수       조식1  ...      석식41      석식42      석식43      석식44  \
# 0      0.671670  0.487869  ...  0.482612  0.145681  0.357469  0.289854
# 1      0.652908  0.450955  ...  0.305344  0.357261  0.354294  0.272619
# 2      0.551595  0.284570  ...  0.569236  0.055868  0.379515  0.365180
# 3      0.604128  0.270653  ...  0.557200  0.260822  0.427856  0.233867
# 4      0.589118  0.558638  ...  0.724165  0.222711  0.177060  0.055158
# 5      0.536585  0.373675  ...  0.305344  0.357261  0.354294  0.272619
# 6      0.540338  0.292359  ...  0.569236  0.055868  0.379515  0.365180
# 7      0.480300  0.278093  ...  0.138472  0.063668  0.759030  0.711394
# 8      0.617261  0.301714  ...  0.541012  0.108659  0.326711  0.289500
# 9      0.617261  0.329916  ...  0.697744  0.229935  0.243168 -0.118688
# 10     0.437148  0.452384  ...  0.627368  0.073643  0.318286  0.190721
# 11     0.666041  0.206827  ...  0.489734  0.203460  0.458062  0.316323
# 12     0.774859  0.373317  ...  0.513229  0.138281  0.378510  0.296820
# 13     0.711069  0.372941  ...  0.404808  0.496094  0.527550  0.158413
# 14     0.634146  0.233937  ...  1.000000  0.048069  0.000000  0.018967
# 15     0.525328  0.385207  ...  0.526589  0.147807  0.388687  0.336191
# 16     0.463415  0.223866  ...  0.388182  0.155043  0.448315  0.319095
# 17     0.437148  0.164810  ...  0.485101  0.247923  0.410861  0.342394
# 18     0.439024  0.345234  ...  0.138472  0.063668  0.759030  0.711394
# 19     0.440901  0.305457  ...  0.569236  0.055868  0.379515  0.365180
# 20     0.335835  0.423021  ...  0.552780  0.180719  0.426602  0.099419
# 21     0.465291  0.278449  ...  0.569236  0.055868  0.379515  0.365180
# 22     0.547842  0.400630  ...  1.000000  0.048069  0.000000  0.018967
# 23     0.493433  0.258115  ...  0.569236  0.055868  0.379515  0.365180
# 24     0.424015  0.427277  ...  0.138472  0.063668  0.759030  0.711394
# 25     0.495310  0.320948  ...  0.459665  0.169139  0.392735  0.246101
# 26     0.529081  0.408606  ...  0.487247  0.194934  0.398658  0.249360
# 27     0.508443  0.382966  ...  0.532768  0.166296  0.385353  0.300103
# 28     0.489681  0.378750  ...  0.305344  0.357261  0.354294  0.272619
# 29     0.470919  0.582278  ...  0.497495  0.190145  0.419054  0.272558
# 30     0.589118  0.327315  ...  0.138472  0.063668  0.759030  0.711394
# 31     0.752345  0.454097  ...  0.501711  0.152146  0.397344  0.295034
# 32     0.696060  0.453857  ...  0.478577  0.223671  0.388587  0.227486
# 33     0.658537  0.305359  ...  0.309430  0.276091  0.788562  0.608264
# 34     0.499062  0.488992  ...  0.499515  0.510517  0.339680  0.098908
# 35     0.656660  0.313634  ...  0.498477  0.043313  0.409064  0.321643
# 36     0.654784  0.422600  ...  0.221065  0.202534  0.706171  0.475868
# 37     0.589118  0.400591  ...  0.471075  0.222957  0.414888  0.237561
# 38     0.557223  0.316317  ...  0.439669  0.175145  0.428441  0.296971
# 39     0.429644  0.395199  ...  0.569236  0.055868  0.379515  0.365180
# 40     0.596623  0.330330  ...  0.138472  0.063668  0.759030  0.711394
# 41     0.587242  0.410262  ...  0.138472  0.063668  0.759030  0.711394
# 42     0.594747  0.425934  ...  0.485101  0.247923  0.410861  0.342394
# 43     0.568480  0.377710  ...  0.516181  0.000000  0.577730  0.473711
# 44     0.420263  0.440533  ...  0.514564  0.003935  0.178560  0.130709
# 45     0.621013  0.302462  ...  0.430478  0.262807  0.528421  0.363102
# 46     0.682927  0.415532  ...  0.138472  0.063668  0.759030  0.711394
# 47     0.626642  0.400373  ...  0.180753  0.084480  0.574150  0.394131
# 48     0.607880  0.236551  ...  1.000000  0.048069  0.000000  0.018967
# 49     0.429644  0.606883  ...  0.486538  0.214397  0.392195  0.256425
#
#         석식45      석식46      석식47      석식48      석식49      석식50
# 0   0.434667  0.456942  0.502784  0.493405  0.396559  0.374559
# 1   0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 2   0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 3   0.418975  0.490002  0.644637  0.346764  0.369667  0.511070
# 4   0.603747  0.317111  0.507354  0.538836  0.586817  0.291170
# 5   0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 6   0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 7   0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 8   0.433144  0.424059  0.561730  0.450340  0.507680  0.355378
# 9   0.531403  0.232778  0.607676  0.465375  0.752809  0.321469
# 10  0.332544  0.396751  0.531288  0.307026  0.493065  0.310596
# 11  0.495649  0.486459  0.610425  0.496529  0.444155  0.389634
# 12  0.420019  0.436348  0.518616  0.446936  0.474735  0.370918
# 13  0.659986  0.606099  1.010483  0.408458  0.422616  1.001235
# 14  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 15  0.397639  0.423982  0.516879  0.465972  0.552408  0.421263
# 16  0.516485  0.478400  0.462598  0.556053  0.438948  0.466847
# 17  0.449698  0.432245  0.521874  0.333134  0.700853  0.586053
# 18  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 19  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 20  0.477718  0.520542  0.502315  0.725153  0.164222  0.451831
# 21  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 22  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 23  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 24  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 25  0.332410  0.399684  0.600940  0.517718  0.460170  0.490646
# 26  0.417959  0.494883  0.597199  0.525223  0.457457  0.448879
# 27  0.461192  0.458476  0.594586  0.430512  0.485485  0.318285
# 28  0.357852  0.523430  0.788132  0.583021  0.453925  0.523642
# 29  0.419315  0.469396  0.581632  0.480964  0.411863  0.425667
# 30  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 31  0.458703  0.398282  0.545170  0.588394  0.434107  0.421567
# 32  0.495903  0.568477  0.590161  0.580982  0.395486  0.509727
# 33  0.339846  0.726229  0.627129  0.271858  0.308801  0.478983
# 34  0.720998  0.402597  0.437898  0.790417  0.332160  0.586029
# 35  0.347902  0.400515  0.643057  0.298954  0.497739  0.258129
# 36  0.320565  0.692642  0.851820  0.282110  0.129555  0.659557
# 37  0.444560  0.498673  0.641809  0.429285  0.451075  0.401751
# 38  0.425300  0.460544  0.575166  0.523967  0.440644  0.423521
# 39  0.412569  0.399900  0.416305  0.475133  0.478734  0.338152
# 40  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 41  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 42  0.449698  0.432245  0.521874  0.333134  0.700853  0.586053
# 43  0.617154  0.386846  0.348615  0.408872  0.701357  0.135933
# 44  0.254754  0.521931  0.671862  0.263578  0.656016  0.434522
# 45  0.436025  0.394389  0.404718  0.420030  0.461737  0.411912
# 46  0.000000  0.799800  0.703640  0.260905  0.259111  0.569656
# 47  0.098101  0.664575  0.891377  0.123331  0.428388  0.463154
# 48  0.825138  0.000000  0.128969  0.689361  0.698357  0.106649
# 49  0.433298  0.493377  0.617264  0.463222  0.444974  0.407696
#
# [50 rows x 159 columns]

# %% [markdown]
# ###**LGBM**

# %%
from sklearn.model_selection import GridSearchCV , cross_val_score
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error

# %%
def get_val_score(model):
    val_pred = model.predict_proba(X_valid)
    return  mean_absolute_error(y_valid,val_pred[:,1])

# %%
#
target_col1 = '중식계'
target_col2 = '석식계'
train_cols = [col for col in train_df.columns if col not in [target_col1 , target_col2]]

# %%
#'중식계'

X_train, X_valid, y_train, y_valid = train_test_split(train_df[train_cols], train_df[target_col1], test_size=0.2, shuffle=True, random_state=34)

lgb_params = {
     'max_depth' : [3,5,8] , 
     'n_estimators': [1000,1200,1500], 
     'learning_rate':[0.01,0.1], 
     'gamma': [0.5], 
     'random_state':[99] }

model = lgb.LGBMRegressor(eval_set=[(X_valid, y_valid)],eval_metric = 'mae')


grid_lgb = GridSearchCV(model, param_grid=lgb_params, cv=3)  # 최소 5 이상 사용 권장
grid_lgb.fit(X_train, y_train)
print(grid_lgb.best_params_)

#Get score
print("="*20)
#print("LGBM Validation MAE : ", get_val_score(grid_lgb))
print("Model1 Score: ",grid_lgb.score(X_valid,y_valid))
print("MAE:",mean_absolute_error(y_valid, grid_lgb.predict(X_valid)))
# Out:
# {'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1500, 'random_state': 99}
# ====================
# Model1 Score:  0.7938393027098887
# MAE: 0.06325242414884587

# %%
pred1 = grid_lgb.predict(test_df)

# %%
pred1
# Out:
# array([0.70408294, 0.57900467, 0.42723064, 0.61204889, 0.58646904,
#        0.49361015, 0.59747276, 0.57155302, 0.66299768, 0.66065201,
#        0.36220007, 0.6747186 , 0.82451745, 0.58228671, 0.52113167,
#        0.3057024 , 0.62401759, 0.82661783, 0.55310171, 0.47965651,
#        0.24235443, 0.82263244, 0.64299464, 0.62137095, 0.3731414 ,
#        0.63481083, 0.85594531, 0.61689853, 0.55473361, 0.39956626,
#        0.65857029, 0.81697743, 0.60601616, 0.56245979, 0.32507999,
#        0.60039085, 0.77308847, 0.51464062, 0.49180325, 0.26553593,
#        0.6242352 , 0.77986304, 0.55216017, 0.50996606, 0.29936955,
#        0.60948172, 0.77755519, 0.54446818, 0.49707549, 0.26983248])

# %%
#'석식계'

X_train, X_valid, y_train, y_valid = train_test_split(train_df[train_cols], train_df[target_col2], test_size=0.2, shuffle=True, random_state=34)

lgb_params = {
     'max_depth' : [3,5,7] , 
     'n_estimators': [1000,1200,1500], 
     'learning_rate':[0.01,0.1], 
     'gamma': [0.5], 
     'random_state':[99] }

model = lgb.LGBMRegressor(eval_set=[(X_valid, y_valid)],eval_metric = 'mae')


grid_lgb = GridSearchCV(model, param_grid=lgb_params, cv=3)
grid_lgb.fit(X_train, y_train)
print(grid_lgb.best_params_)

#Get score
print("="*20)
print("Model2 Score: ",grid_lgb.score(X_valid,y_valid))
print("MAE:",mean_absolute_error(y_valid, grid_lgb.predict(X_valid)))
# Out:
# {'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1200, 'random_state': 99}
# ====================
# Model2 Score:  0.757219954262221
# MAE: 0.05286469898592169

# %%
pred2 = grid_lgb.predict(test_df)

# %%
pred2
# Out:
# array([0.37991666, 0.29885071, 0.29788347, 0.57869454, 0.44989639,
#        0.2261214 , 0.52827201, 0.42453541, 0.52542733, 0.49119274,
#        0.22279861, 0.76813417, 0.72785441, 0.41228007, 0.4591476 ,
#        0.38138928, 0.73908023, 0.7515066 , 0.4432717 , 0.55337547,
#        0.29586291, 0.6894076 , 0.34848144, 0.60009779, 0.4239164 ,
#        0.71857479, 0.70812853, 0.42144243, 0.36017495, 0.35750841,
#        0.75394077, 0.5962208 , 0.38689232, 0.48952493, 0.26565497,
#        0.59935882, 0.60899226, 0.37919902, 0.48427569, 0.31425474,
#        0.63820916, 0.61002532, 0.41300346, 0.52928684, 0.23356366,
#        0.5838723 , 0.60726045, 0.43402302, 0.36873484, 0.34185915])

# %%
#pred1 = 중식 , pred2 = 석식 두개를 
test_pred = pd.DataFrame([pred1, pred2]).T
test_pred.columns = ['중식계', '석식계']


test_pred = mm.inverse_transform(test_pred)
test_pred = pd.DataFrame(test_pred, columns = ['중식계','석식계'])
test_pred
# Out:
#             중식계         석식계
# 0   1114.848462  343.824573
# 1    969.382435  270.459888
# 2    792.869232  269.584543
# 3   1007.812856  523.718554
# 4    978.063490  407.156236
# 5    870.068608  204.639869
# 6    990.860825  478.086169
# 7    960.716160  384.204544
# 8   1067.066299  475.511730
# 9   1064.338288  444.529430
# 10   717.238686  201.632742
# 11  1080.697734  695.161421
# 12  1254.913799  658.708242
# 13   973.199449  373.113465
# 14   902.076134  415.528578
# 15   651.531891  345.157300
# 16  1021.732460  668.867608
# 17  1257.356541  680.113472
# 18   939.257288  401.160890
# 19   853.840519  500.804797
# 20   577.858207  267.755932
# 21  1252.721526  623.913875
# 22  1043.802771  315.375701
# 23  1018.654420  543.088503
# 24   729.963454  383.644340
# 25  1034.284991  650.310183
# 26  1291.464391  640.856323
# 27  1013.452990  381.405397
# 28   941.155187  325.958327
# 29   760.695560  323.545111
# 30  1061.917252  682.316393
# 31  1246.144757  539.579822
# 32  1000.796794  350.137552
# 33   950.140732  443.020065
# 34   674.068033  240.417752
# 35   994.254554  542.419732
# 36  1195.101892  551.137998
# 37   894.527045  343.175114
# 38   867.967184  438.269500
# 39   604.818281  284.400536
# 40  1021.985532  577.579287
# 41  1202.980719  552.072911
# 42   938.162277  373.768128
# 43   889.090533  479.004589
# 44   644.166786  211.375114
# 45  1004.827244  528.404427
# 46  1200.296683  549.570703
# 47   929.216492  392.790835
# 48   874.098797  333.705030
# 49   609.815174  309.382529

# %%
sub = sub.drop(['중식계','석식계'], axis = 1)
sub = pd.concat( [sub,test_pred], axis= 1)
sub
# Out:
#             일자          중식계         석식계
# 0   2021-01-27  1114.848462  343.824573
# 1   2021-01-28   969.382435  270.459888
# 2   2021-01-29   792.869232  269.584543
# 3   2021-02-01  1007.812856  523.718554
# 4   2021-02-02   978.063490  407.156236
# 5   2021-02-03   870.068608  204.639869
# 6   2021-02-04   990.860825  478.086169
# 7   2021-02-05   960.716160  384.204544
# 8   2021-02-08  1067.066299  475.511730
# 9   2021-02-09  1064.338288  444.529430
# 10  2021-02-10   717.238686  201.632742
# 11  2021-02-15  1080.697734  695.161421
# 12  2021-02-16  1254.913799  658.708242
# 13  2021-02-17   973.199449  373.113465
# 14  2021-02-18   902.076134  415.528578
# 15  2021-02-19   651.531891  345.157300
# 16  2021-02-22  1021.732460  668.867608
# 17  2021-02-23  1257.356541  680.113472
# 18  2021-02-24   939.257288  401.160890
# 19  2021-02-25   853.840519  500.804797
# 20  2021-02-26   577.858207  267.755932
# 21  2021-03-02  1252.721526  623.913875
# 22  2021-03-03  1043.802771  315.375701
# 23  2021-03-04  1018.654420  543.088503
# 24  2021-03-05   729.963454  383.644340
# 25  2021-03-08  1034.284991  650.310183
# 26  2021-03-09  1291.464391  640.856323
# 27  2021-03-10  1013.452990  381.405397
# 28  2021-03-11   941.155187  325.958327
# 29  2021-03-12   760.695560  323.545111
# 30  2021-03-15  1061.917252  682.316393
# 31  2021-03-16  1246.144757  539.579822
# 32  2021-03-17  1000.796794  350.137552
# 33  2021-03-18   950.140732  443.020065
# 34  2021-03-19   674.068033  240.417752
# 35  2021-03-22   994.254554  542.419732
# 36  2021-03-23  1195.101892  551.137998
# 37  2021-03-24   894.527045  343.175114
# 38  2021-03-25   867.967184  438.269500
# 39  2021-03-26   604.818281  284.400536
# 40  2021-03-29  1021.985532  577.579287
# 41  2021-03-30  1202.980719  552.072911
# 42  2021-03-31   938.162277  373.768128
# 43  2021-04-01   889.090533  479.004589
# 44  2021-04-02   644.166786  211.375114
# 45  2021-04-05  1004.827244  528.404427
# 46  2021-04-06  1200.296683  549.570703
# 47  2021-04-07   929.216492  392.790835
# 48  2021-04-08   874.098797  333.705030
# 49  2021-04-09   609.815174  309.382529

# %%
sub.to_csv('sample_submission.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# ###**LinearReg**

# %%
from sklearn.linear_model import LinearRegression

# %%
# '중식계'

X_train, X_valid, y_train, y_valid = train_test_split(train_df[train_cols], train_df[target_col1], test_size=0.2, shuffle=True, random_state=34)

lin_reg = LinearRegression()

lin_reg.fit(X_train,y_train)
y_valid_predict = lin_reg.predict(X_valid)

print("Model3 Score: ",lin_reg.score(X_valid,y_valid))
print("MAE:",mean_absolute_error(y_valid, lin_reg.predict(X_valid)))

# %%
pred3 = lin_reg.predict(test_df)

# %%
pred3

# %%
# '석식계'

X_train, X_valid, y_train, y_valid = train_test_split(train_df[train_cols], train_df[target_col2], test_size=0.2, shuffle=True, random_state=34)

lin_reg = LinearRegression()

lin_reg.fit(X_train,y_train)
y_valid_predict = lin_reg.predict(X_valid)


print("Model4 Score: ",lin_reg.score(X_valid,y_valid))
print("MAE:",mean_absolute_error(y_valid, lin_reg.predict(X_valid)))

# %%
pred4 = lin_reg.predict(test_df)

# %%
pred4
